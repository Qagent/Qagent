# %% [markdown]
# <a href="https://colab.research.google.com/github/Qagent/Qagent/blob/main/pre_processipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
from importlib import import_module
import numpy as np
import csv
import pandas as pd 
import gc
import itertools as it
import collections
import re
import io
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #class

# %%
class data_cleaner():
  def __init__(self,dataframe,col_name):
    self.data = data
    self.col_name = col_name
  
  def regex_dict():
    re_dict = {
               '(\?){1,}':' ? ',
               '(,){1,}':' , ',
               '(\.){1,}':' . ',
               '(\n){1,}':'\n',
               '(<.*>){1,}':' ',
               '(\!){1,}':' ! ',
               '(\*){1,}':' . ',
               '(\|){1,}':' | ',
               '([\xa0]){1,}':' ',
               '("){1,}':' " ',
               '(\. ){1,}':' . ',
               '(~){1,}':' ',
               '(-){1,}':' ',
               '(:){1,}':' ',
               '(\s){1,}':' ' 
               }
    return re_dict

  def char_dict():
    char_dict = {'0': 'v',
                '1': 'ৈ',
                '2': 'ঢ',
                '3': 'ঃ',
                '4': 'ঞ',
                '5': ')',
                '6': '5',
                '7': 'ছ',
                '8': 'h',
                '9': '/',
                '10': '৩',
                '11': 'ঋ',
                '12': 'য়',
                '13': 'ষ',
                '14': 'ও',
                '15': 'জ',
                '16': 'ড',
                '17': 'l',
                '18': 'ো',
                '19': 'ু',
                '20': 'প',
                '21': 'স',
                '22': 'ং',
                '23': 'য',
                '24': 'a',
                '25': '?',
                '26': 'হ',
                '27': 's',
                '28': 'm',
                '29': 'ল',
                '30': '০',
                '31': '৷',
                '32': '️',
                '33': 'u',
                '34': 'ন',
                '35': 'ক',
                '36': 'w',
                '37': "'",
                '38': 'া',
                '39': ' ',
                '40': '3',
                '41': 'n',
                '42': '৭',
                '43': 'গ',
                '44': '৯',
                '45': 'ঘ',
                '46': '8',
                '47': '-',
                '48': '#',
                '49': '১',
                '50': 'ৎ',
                '51': 'উ',
                '52': 'ঁ',
                '53': ';',
                '54': 'দ',
                '55': 'ত',
                '56': 'e',
                '57': 'ৌ',
                '58': '=',
                '59': '|',
                '60': 'ূ',
                '61': 'শ',
                '62': 'ই',
                '63': '6',
                '64': '2',
                '65': '0',
                '66': 'i',
                '67': 't',
                '68': 'k',
                '69': 'ম',
                '70': '!',
                '71': '”',
                '72': '়',
                '73': '“',
                '74': '.',
                '75': 'অ',
                '76': 'চ',
                '77': 'ী',
                '78': '7',
                '79': '৪',
                '80': 'খ',
                '81': '’',
                '82': '(',
                '83': '9',
                '84': '"',
                '85': 'ণ',
                '86': 'ট',
                '87': 'o',
                '88': 'p',
                '89': '২',
                '90': 'ে',
                '91': 'ফ',
                '92': '1',
                '93': '।',
                '94': 'এ',
                '95': '৬',
                '96': 'y',
                '97': 'ঠ',
                '98': 'ধ',
                '99': 'ড়',
                '100': 'f',
                '101': 'r',
                '102': '*',
                '103': 'c',
                '104': 'আ',
                '105': '্',
                '106': ':',
                '107': '_',
                '108': 'থ',
                '109': '৫',
                '110': '৮',
                '111': 'ঝ',
                '112': 'ভ',
                '113': 'b',
                '114': 'ঙ',
                '115': 'র',
                '116': 'ব',
                '117': 'g',
                '118': 'd',
                '119': ',',
                '120': 'ৃ',
                '121': 'ি',
                '122': 'ঐ',
                '123': '4',
                '124': 'े',
                '125': 'ന',
                '126': 'त',
                '127': 'ा',
                '128': 'x',
                '129': 'z',
                '130': 'क',
                '131': 'j',
                '132': 'ി',
                '133': '്',
                '134': 'ૉ',
                '135': 'ઉ',
                '136': 'આ',
                '137': 'ઢ',
                '138': 'ઇ',
                '139': 'ં',
                '140': 'ફ',
                '141': 'ગ',
                '142': 'શ',
                '143': 'સ',
                '144': 'પ',
                '145': 'વ',
                '146': '્',
                '147': 'બ',
                '148': 'ૌ',
                '149': 'હ',
                '150': 'ક',
                '151': 'મ',
                '152': 'િ',
                '153': 'ૈ',
                '154': 'ો',
                '155': 'અ',
                '156': '૨',
                '157': 'ત',
                '158': 'ી',
                '159': 'ર',
                '160': 'ષ',
                '161': 'થ',
                '162': 'ુ',
                '163': 'ચ',
                '164': '૧',
                '165': 'ૃ',
                '166': 'ડ',
                '167': 'લ',
                '168': 'જ',
                '169': 'ણ',
                '170': 'ભ',
                '171': 'ઈ',
                '172': 'દ',
                '173': 'એ',
                '174': 'છ',
                '175': 'ઓ',
                '176': 'ઘ',
                '177': 'ઊ',
                '178': 'ન',
                '179': 'ઝ',
                '180': 'ે',
                '181': 'ા',
                '182': 'ળ',
                '183': 'ધ',
                '184': 'ય',
                '185': 'ઠ',
                '186': 'ૂ',
                '187': 'ટ',
                '188': 'ખ',
                '189': 'ज',
                '190': '१',
                '191': 'ज़',
                '192': 'इ',
                '193': 'ै',
                '194': 'ृ',
                '195': 'ष',
                '196': 'च',
                '197': 'औ',
                '198': 'क़',
                '199': 'ढ़',
                '200': 'ः',
                '201': 'ॅ',
                '202': '…',
                '203': 'ऋ',
                '204': 'ध',
                '205': 'ऐ',
                '206': 'झ',
                '207': 'ि',
                '208': 'ं',
                '209': 'ँ',
                '210': 'फ',
                '211': 'ो',
                '212': 'र',
                '213': 'न',
                '214': 'छ',
                '215': 'ौ',
                '216': 'द',
                '217': '‘',
                '218': 'ञ',
                '219': 'ब',
                '220': 'स',
                '221': 'ह',
                '222': 'ी',
                '223': 'ख',
                '224': 'म',
                '225': 'य',
                '226': '–',
                '227': 'ॉ',
                '228': 'ऑ',
                '229': 'ख़',
                '230': 'आ',
                '231': 'थ',
                '232': 'फ़',
                '233': '्',
                '234': 'ड',
                '235': 'ऊ',
                '236': 'ओ',
                '237': 'ण',
                '238': '~',
                '239': '☺',
                '240': 'ु',
                '241': 'ढ',
                '242': 'ई',
                '243': 'भ',
                '244': '•',
                '245': '़',
                '246': 'प',
                '247': 'अ',
                '248': 'ल',
                '249': 'ठ',
                '250': 'ग',
                '251': 'घ',
                '252': 'ए',
                '253': 'उ',
                '254': 'ड़',
                '255': 'श',
                '256': 'ट',
                '257': 'ू',
                '258': 'व',
                '259': 'ಷ',
                '260': 'ಆ',
                '261': 'ಚ',
                '262': 'ೌ',
                '263': 'ಘ',
                '264': 'ೆ',
                '265': 'ಂ',
                '266': 'ಬ',
                '267': 'ವ',
                '268': 'ಎ',
                '269': 'ಇ',
                '270': 'ೋ',
                '271': 'ಟ',
                '272': '೨',
                '273': 'ಾ',
                '274': 'ದ',
                '275': 'ಓ',
                '276': 'ಉ',
                '277': 'ಯ',
                '278': 'ಸ',
                '279': 'ಿ',
                '280': '್',
                '281': 'ಫ',
                '282': 'ಥ',
                '283': 'ಅ',
                '284': 'ಣ',
                '285': 'ಮ',
                '286': 'ೈ',
                '287': '೧',
                '288': 'ಈ',
                '289': 'ೃ',
                '290': 'ರ',
                '291': 'ೂ',
                '292': 'ೀ',
                '293': 'ಠ',
                '294': 'ನ',
                '295': 'ು',
                '296': 'ಊ',
                '297': 'ೊ',
                '298': 'ಭ',
                '299': 'ಧ',
                '300': 'ಒ',
                '301': 'ಹ',
                '302': 'ಕ',
                '303': 'ಲ',
                '304': 'ಗ',
                '305': 'ಖ',
                '306': 'ಪ',
                '307': 'ತ',
                '308': 'ಜ',
                '309': 'ಶ',
                '310': 'ಏ',
                '311': 'ೇ',
                '312': 'ಡ',
                '313': 'ಳ',
                '314': 'ಐ',
                '315': 'പ',
                '316': 'ങ',
                '317': 'ള',
                '318': 'ീ',
                '319': 'ഃ',
                '320': '❣',
                '321': 'ശ',
                '322': 'ഞ',
                '323': 'മ',
                '324': 'ഥ',
                '325': 'ഴ',
                '326': 'ആ',
                '327': 'ഭ',
                '328': 'ഫ',
                '329': '°',
                '330': 'ഇ',
                '331': 'ഛ',
                '332': 'ഘ',
                '333': 'ൺ',
                '334': 'ച',
                '335': 'ാ',
                '336': 'ഒ',
                '337': '©',
                '338': '<',
                '339': 'യ',
                '340': 'േ',
                '341': 'ൽ',
                '342': 'ല',
                '343': '🎶',
                '344': 'ഗ',
                '345': 'ക',
                '346': 'ൃ',
                '347': 'ം',
                '348': 'ത',
                '349': 'ർ',
                '350': 'ദ',
                '351': '@',
                '352': 'െ',
                '353': 'ഈ',
                '354': 'ഡ',
                '355': 'ഏ',
                '356': 'ട',
                '357': 'ൻ',
                '358': 'ബ',
                '359': 'എ',
                '360': 'ഖ',
                '361': 'സ',
                '362': 'ഓ',
                '363': '⃣',
                '364': 'ഐ',
                '365': 'റ',
                '366': 'ോ',
                '367': 'ൾ',
                '368': 'ൂ',
                '369': 'ഷ',
                '370': 'അ',
                '371': 'വ',
                '372': 'ഉ',
                '373': 'ൈ',
                '374': 'ഹ',
                '375': 'ണ',
                '376': 'ര',
                '377': 'ജ',
                '378': 'ഠ',
                '379': 'ു',
                '380': '>',
                '381': 'ൗ',
                '382': 'ൊ',
                '383': 'ധ',
                '384': '३',
                '385': '७',
                '386': '६',
                '387': '४',
                '388': '२',
                '389': '५',
                '390': 'ऱ',
                '391': '०',
                '392': 'ळ',
                '393': 'ଆ',
                '394': 'ୌ',
                '395': 'ି',
                '396': 'ଞ',
                '397': 'ୁ',
                '398': 'ୂ',
                '399': 'ଂ',
                '400': 'ୈ',
                '401': 'ଢ',
                '402': 'ଗ',
                '403': 'ମ',
                '404': 'ଃ',
                '405': 'ଖ',
                '406': '୧',
                '407': 'ଣ',
                '408': 'ଥ',
                '409': 'ଵ',
                '410': 'ଜ',
                '411': '୨',
                '412': 'ଫ',
                '413': 'ଓ',
                '414': 'ଯ',
                '415': 'ର',
                '416': 'ା',
                '417': 'ଘ',
                '418': 'ପ',
                '419': 'ୀ',
                '420': 'ଭ',
                '421': 'କ',
                '422': 'ତ',
                '423': 'ଶ',
                '424': 'ଷ',
                '425': 'ଡ଼',
                '426': 'ଠ',
                '427': 'ଧ',
                '428': 'ଇ',
                '429': 'ହ',
                '430': 'ଲ',
                '431': 'ଏ',
                '432': 'ୱ',
                '433': '଼',
                '434': 'ୋ',
                '435': 'ଦ',
                '436': 'ୃ',
                '437': '୍',
                '438': 'େ',
                '439': 'ସ',
                '440': 'ନ',
                '441': 'ଚ',
                '442': 'ଙ',
                '443': 'ଉ',
                '444': 'ଛ',
                '445': 'ଅ',
                '446': 'ଁ',
                '447': 'ଳ',
                '448': 'ଡ',
                '449': 'ୟ',
                '450': 'ଟ',
                '451': 'ଝ',
                '452': 'ବ',
                '453': '୦',
                '454': 'ਕ',
                '455': 'ਝ',
                '456': 'ਖ',
                '457': 'ੌ',
                '458': 'ੜ',
                '459': 'ਵ',
                '460': 'ਮ',
                '461': 'ਯ',
                '462': 'ਊ',
                '463': 'ਤ',
                '464': 'ਗ',
                '465': 'ਔ',
                '466': 'ਭ',
                '467': '੍',
                '468': 'ਪ',
                '469': 'ਜ਼',
                '470': 'ਂ',
                '471': 'ੰ',
                '472': 'ਆ',
                '473': 'ਦ',
                '474': 'ਥ',
                '475': 'ਧ',
                '476': 'ੲ',
                '477': 'ਚ',
                '478': 'ਅ',
                '479': '਼',
                '480': 'ਓ',
                '481': 'ਬ',
                '482': 'ਣ',
                '483': 'ਨ',
                '484': 'ਘ',
                '485': 'ਠ',
                '486': 'ਛ',
                '487': 'ੇ',
                '488': 'ੀ',
                '489': 'ਾ',
                '490': 'ਏ',
                '491': 'ਐ',
                '492': 'ਸ਼',
                '493': 'ੁ',
                '494': 'ੂ',
                '495': 'ਉ',
                '496': 'ਟ',
                '497': 'ਈ',
                '498': 'ਇ',
                '499': 'ੈ',
                '500': 'ਲ',
                '501': 'ੳ',
                '502': 'ਫ',
                '503': 'ਜ',
                '504': 'ੋ',
                '505': 'ਢ',
                '506': 'ਡ',
                '507': 'ਿ',
                '508': 'ਰ',
                '509': 'ਹ',
                '510': 'ੱ',
                '511': 'ਸ',
                '512': 'ம',
                '513': 'ழ',
                '514': '%',
                '515': 'அ',
                '516': 'ஏ',
                '517': 'ஷ',
                '518': 'ஜ',
                '519': 'வ',
                '520': 'ஹ',
                '521': 'ட',
                '522': 'ஸ',
                '523': 'ந',
                '524': 'எ',
                '525': 'ப',
                '526': 'ர',
                '527': 'க',
                '528': 'ி',
                '529': 'ய',
                '530': 'ல',
                '531': 'ஊ',
                '532': 'ா',
                '533': 'ங',
                '534': 'ற',
                '535': 'ௌ',
                '536': 'ன',
                '537': 'ஃ',
                '538': 'ொ',
                '539': 'ஒ',
                '540': 'த',
                '541': 'ஐ',
                '542': 'ண',
                '543': 'ஞ',
                '544': 'ை',
                '545': 'ூ',
                '546': 'ள',
                '547': 'ச',
                '548': 'இ',
                '549': 'ோ',
                '550': 'ீ',
                '551': 'ெ',
                '552': 'ு',
                '553': '்',
                '554': 'உ',
                '555': 'ஆ',
                '556': 'ே',
                '557': 'ஓ',
                '558': 'ౌ',
                '559': 'ఇ',
                '560': 'జ',
                '561': 'ో',
                '562': 'త',
                '563': 'ధ',
                '564': 'డ',
                '565': 'ట',
                '566': 'స',
                '567': 'వ',
                '568': 'గ',
                '569': 'థ',
                '570': 'హ',
                '571': 'ఏ',
                '572': 'ష',
                '573': 'మ',
                '574': 'ఉ',
                '575': 'క',
                '576': 'ొ',
                '577': 'ఐ',
                '578': 'ీ',
                '579': 'ూ',
                '580': 'ణ',
                '581': 'ద',
                '582': '్',
                '583': 'ై',
                '584': 'ఎ',
                '585': 'ళ',
                '586': 'ఓ',
                '587': 'ఫ',
                '588': 'ఒ',
                '589': 'ఆ',
                '590': 'య',
                '591': 'ి',
                '592': 'ల',
                '593': 'ె',
                '594': 'అ',
                '595': 'ా',
                '596': 'న',
                '597': 'శ',
                '598': 'ఈ',
                '599': 'ఊ',
                '600': 'భ',
                '601': 'ు',
                '602': 'ే',
                '603': 'ఘ',
                '604': 'బ',
                '605': 'చ',
                '606': 'ర',
                '607': 'ఖ',
                '608': 'ం',
                '609': 'ప',
                '610': 'ృ',
                '611': 'د',
                '612': 'ھ',
                '613': 'س',
                '614': 'ذ',
                '615': 'ڈ',
                '616': 'ہ',
                '617': 'ث',
                '618': 'ظ',
                '619': 'ک',
                '620': 'ی',
                '621': 'گ',
                '622': 'ح',
                '623': 'ئ',
                '624': 'ؤ',
                '625': 'پ',
                '626': 'ڑ',
                '627': 'ٹ',
                '628': '؟',
                '629': 'چ',
                '630': 'ں',
                '631': '۔',
                '632': 'خ',
                '633': 'ض',
                '634': 'ز',
                '635': 'غ',
                '636': 'ت',
                '637': 'م',
                '638': 'ب',
                '639': 'ج',
                '640': 'ُ',
                '641': 'ا',
                '642': 'ے',
                '643': 'و',
                '644': 'ر',
                '645': 'ط',
                '646': '،',
                '647': 'ف',
                '648': 'ن',
                '649': 'آ',
                '650': 'ع',
                '651': 'ش',
                '652': 'ص',
                '653': 'ق',
                '654': 'ل'}
    return char_dict

  def regex_clean(self,col_name,data):
    re_dict = data_cleaner.regex_dict()
    data[col_name] = data[col_name].replace(re_dict,regex = True)
    data = data[(data[col_name] != '<NA>') & (~data[col_name].isnull()) & (data[col_name] != ' ')]
    return data
  
  def char_clean(self,col_name,data):
    char_dict = data_cleaner.char_dict()
    def col_clean(str_data):
      str_data = str(str_data)
      chk =[str_data[i].lower() for i in range(len(str_data))]
      def filt(da):
        if da in char_dict.values():
          return da
        else: 
          return ''
      new_a = list(map(filt,chk))
      new_a = "".join(new_a)
      if len(new_a) < 1:
        new_a = "none"
      else:
        new_a = new_a
      return new_a 
    data[col_name] = data[col_name].apply(col_clean)
    return data

  def pre_process(self):
    data = self.data
    col_name = self.col_name
    data = self.regex_clean(col_name ,data)
    data = self.char_clean(col_name,data)
    data = self.regex_clean(col_name,data)
    data = data[(data[col_name] != '<NA>') & (~data[col_name].isnull()) & (data[col_name] != 'none')]
    return data

# %% [markdown]
# #text_run

# %%
data = pd.read_csv('/content/drive/My Drive/all_lang_meta/english/SERIES_PRATILIPI_DATA_ENGLISH.csv',on_bad_lines = 'skip',sep = ',', skip_blank_lines = True,encoding = 'utf8',encoding_errors = "ignore")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'pratilipi_id', 'series_id', 'part', 'is_active',
#        'author_id', 'title', 'title_en', 'slug_id', 'published_at',
#        'reading_time', 'category.action-and-adventure', 'category.drama',
#        'category.life', 'category.romance', 'category.science-fiction',
#        'category.shortstories', 'category.suspense', 'name_en', 'rating_count',
#        'reviews_count', 'average_rating', 'ADB_READ_FINISH', 'rate_sum',
#        'total_time_spent_by_readers'],
#       dtype='object')

# %%
data = data[['series_id','title']]

# %%
data
# Out:
#        series_id                                title
# 0          18919                          T.E.A.M 5.1
# 1          18919                 TEAM 5.1 (BEGINNING)
# 2          18919           T.E.A.M 5.1 (Way To India)
# 3          18919               T.E.A.M. 5.1 .Sridhar.
# 4          19256                            Ryuusei 1
# ...          ...                                  ...
# 39796     536388                    Our Wedding ? (2)
# 39797     536388                    Our Wedding ? (3)
# 39798     536388                    Our Wedding ? (4)
# 39799     537854  ?\n  ???????? ?????????  \n\n\n\n??
# 39800     539137                       The Hitchhiker
#
# [39801 rows x 2 columns]

# %%
data = data_cleaner(data,'title').pre_process()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:707: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:686: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data
# Out:
#        series_id                               title
# 0          18919                 t . e . a . m 5 . 1
# 1          18919              team 5 . 1 (beginning)
# 2          18919  t . e . a . m 5 . 1 (way to india)
# 3          18919  t . e . a . m . 5 . 1 . sridhar .
# 4          19256                           ryuusei 1
# ...          ...                                 ...
# 39796     536388                   our wedding ? (2)
# 39797     536388                   our wedding ? (3)
# 39798     536388                   our wedding ? (4)
# 39799     537854                            ? ? ? ?
# 39800     539137                      the hitchhiker
#
# [39798 rows x 2 columns]

# %%
list(data[data['series_id'] == 537854]['title'])
# Out:
# [' ? ? ? ? ']
